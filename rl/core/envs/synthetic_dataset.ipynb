# %%
#@title Install PyTorch
# !pip3 install torch torchvision

# %%
#@title Imports
import math
from matplotlib import pyplot as plt
import numpy as np
import torch as th


# %load_ext autoreload
# %autoreload 2

def show_image(image):
  image = image.squeeze()
  plt.imshow(image, cmap='gray')
  plt.axis('off')

# %%
from rl.core.envs import synthetic_dataset

# %%
ds = synthetic_dataset.MnistSyntheticDataset(
    width=200, height=150, num_images=10, tiles_per_image=6)

# %%
for i in range(3):
  plt.figure()
  show_image(ds.images[i, ...])
