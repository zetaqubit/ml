# %% [markdown]
# ## Install

# %%
# !pip3 install torch torchvision numpy

# %% [markdown]
# ## Imports

# %%
from matplotlib import pyplot as plt
import numpy as np

import torch as th
from torch import nn

from pytorch.examples.yunjey import ptb_data

# %% [markdown]
# ## Config

# %%
device = th.device('cuda' if th.cuda.is_available() else 'cpu')
print(f'Using {device}')


embed_size = 128
hidden_size = 1024
num_layers = 1


num_epochs = 5
num_samples = 1000  # number of words to sample during eval.
batch_size = 20
seq_length = 30
learning_rate = 0.002
# Out:
# Using cuda

# %% [markdown]
# ## Dataset (Penn Treebank)

# %%
corpus = ptb_data.Corpus()
ids = corpus.get_data('pytorch/examples/yunjey/ptb_data/train.txt', batch_size)
vocab_size = len(corpus.dictionary)
num_batches = ids.size(1) // seq_length

# %%
print(ids.shape)
print(vocab_size)
print(num_batches)
# Out:
# torch.Size([20, 46479])
# 10000
# 1549

# %% [markdown]
# ## Model (RNN LM)

# %%
class RNNLM(nn.Module):
  def __init__(self, vocab_size, embed_size, hidden_size, num_layers):
    super(RNNLM, self).__init__()
    self.embed = nn.Embedding(vocab_size, embed_size)
    self.lstm = nn.LSTM(embed_size, hidden_size, num_layers, batch_first=True)
    self.fc = nn.Linear(hidden_size, vocab_size)
    
  def forward(self, x, h):
    # Embed word ids to vectors.
    x = self.embed(x)
    
    # Forward propagate LSTM.
    out, (h, c) = self.lstm(x, h)
    
    # Reshape output to (batch_size * seq_length, hidden_size).
    out = out.reshape(-1, out.size(2))
    
    # Decode the hidden states of all time steps.
    out = self.fc(out)
    return out, (h, c)

model = RNNLM(vocab_size, embed_size, hidden_size, num_layers).to(device)

# %% [markdown]
# ## Train

# %%
# Loss and optimizer.
loss_fn = nn.CrossEntropyLoss()
optimizer = th.optim.Adam(model.parameters(), lr=learning_rate)

# Truncated backpropagation.
def detach(states):
  return [state.detach() for state in states]

# Train.
for epoch in range(num_epochs):
  # Set initial hidden and cell states.
  states = (th.zeros(num_layers, batch_size, hidden_size).to(device),
            th.zeros(num_layers, batch_size, hidden_size).to(device))
  
  for i in range(0, ids.size(1) - seq_length, seq_length):
    inputs = ids[:, i:i+seq_length].to(device)
    targets = ids[:, i+1:i+1+seq_length].to(device)

    # Forward
    states = detach(states)
    outputs, states = model(inputs, states)
    loss = loss_fn(outputs, targets.reshape(-1))
    
    # Backward
    optimizer.zero_grad()
    loss.backward()
    nn.utils.clip_grad_norm_(model.parameters(), 0.5)
    optimizer.step()
    
    step = (i + 1) // seq_length
    if step % 100 == 0:
      print(f'Epoch [{epoch+1}/{num_epochs}], Step [{step}/{num_batches}], '
            f'Loss: {loss.item():.4}, '
            f'Perplexity: {np.exp(loss.item()):5.2f}')
# Out:
# Epoch [1/5], Step [0/1549], Loss: 9.21, Perplexity: 9995.55
# Epoch [1/5], Step [100/1549], Loss: 5.984, Perplexity: 397.11
# Epoch [1/5], Step [200/1549], Loss: 5.942, Perplexity: 380.69
# Epoch [1/5], Step [300/1549], Loss: 5.753, Perplexity: 315.04
# Epoch [1/5], Step [400/1549], Loss: 5.707, Perplexity: 300.88
# Epoch [1/5], Step [500/1549], Loss: 5.152, Perplexity: 172.82
# Epoch [1/5], Step [600/1549], Loss: 5.138, Perplexity: 170.43
# Epoch [1/5], Step [700/1549], Loss: 5.327, Perplexity: 205.77
# Epoch [1/5], Step [800/1549], Loss: 5.189, Perplexity: 179.36
# Epoch [1/5], Step [900/1549], Loss: 5.057, Perplexity: 157.07
# Epoch [1/5], Step [1000/1549], Loss: 5.107, Perplexity: 165.14
# Epoch [1/5], Step [1100/1549], Loss: 5.321, Perplexity: 204.52
# Epoch [1/5], Step [1200/1549], Loss: 5.191, Perplexity: 179.66
# Epoch [1/5], Step [1300/1549], Loss: 5.084, Perplexity: 161.35
# Epoch [1/5], Step [1400/1549], Loss: 4.873, Perplexity: 130.69
# Epoch [1/5], Step [1500/1549], Loss: 5.193, Perplexity: 180.05
# Epoch [2/5], Step [0/1549], Loss: 5.413, Perplexity: 224.25
# Epoch [2/5], Step [100/1549], Loss: 4.568, Perplexity: 96.39
# Epoch [2/5], Step [200/1549], Loss: 4.723, Perplexity: 112.55
# Epoch [2/5], Step [300/1549], Loss: 4.688, Perplexity: 108.67
# Epoch [2/5], Step [400/1549], Loss: 4.551, Perplexity: 94.76
# Epoch [2/5], Step [500/1549], Loss: 4.124, Perplexity: 61.78
# Epoch [2/5], Step [600/1549], Loss: 4.396, Perplexity: 81.10
# Epoch [2/5], Step [700/1549], Loss: 4.376, Perplexity: 79.52
# Epoch [2/5], Step [800/1549], Loss: 4.397, Perplexity: 81.25
# Epoch [2/5], Step [900/1549], Loss: 4.158, Perplexity: 63.91
# Epoch [2/5], Step [1000/1549], Loss: 4.3, Perplexity: 73.69
# Epoch [2/5], Step [1100/1549], Loss: 4.496, Perplexity: 89.68
# Epoch [2/5], Step [1200/1549], Loss: 4.518, Perplexity: 91.65
# Epoch [2/5], Step [1300/1549], Loss: 4.211, Perplexity: 67.39
# Epoch [2/5], Step [1400/1549], Loss: 3.947, Perplexity: 51.77
# Epoch [2/5], Step [1500/1549], Loss: 4.358, Perplexity: 78.13
# Epoch [3/5], Step [0/1549], Loss: 4.444, Perplexity: 85.12
# Epoch [3/5], Step [100/1549], Loss: 3.881, Perplexity: 48.45
# Epoch [3/5], Step [200/1549], Loss: 4.095, Perplexity: 60.06
# Epoch [3/5], Step [300/1549], Loss: 3.975, Perplexity: 53.23
# Epoch [3/5], Step [400/1549], Loss: 3.8, Perplexity: 44.71
# Epoch [3/5], Step [500/1549], Loss: 3.398, Perplexity: 29.89
# Epoch [3/5], Step [600/1549], Loss: 3.832, Perplexity: 46.16
# Epoch [3/5], Step [700/1549], Loss: 3.753, Perplexity: 42.66
# Epoch [3/5], Step [800/1549], Loss: 3.777, Perplexity: 43.70
# Epoch [3/5], Step [900/1549], Loss: 3.439, Perplexity: 31.17
# Epoch [3/5], Step [1000/1549], Loss: 3.613, Perplexity: 37.09
# Epoch [3/5], Step [1100/1549], Loss: 3.759, Perplexity: 42.91
# Epoch [3/5], Step [1200/1549], Loss: 3.794, Perplexity: 44.45
# Epoch [3/5], Step [1300/1549], Loss: 3.477, Perplexity: 32.37
# Epoch [3/5], Step [1400/1549], Loss: 3.23, Perplexity: 25.28
# Epoch [3/5], Step [1500/1549], Loss: 3.633, Perplexity: 37.82
# Epoch [4/5], Step [0/1549], Loss: 3.522, Perplexity: 33.85
# Epoch [4/5], Step [100/1549], Loss: 3.293, Perplexity: 26.91
# Epoch [4/5], Step [200/1549], Loss: 3.466, Perplexity: 32.01
# Epoch [4/5], Step [300/1549], Loss: 3.467, Perplexity: 32.05
# Epoch [4/5], Step [400/1549], Loss: 3.336, Perplexity: 28.11
# Epoch [4/5], Step [500/1549], Loss: 2.908, Perplexity: 18.32
# Epoch [4/5], Step [600/1549], Loss: 3.435, Perplexity: 31.04
# Epoch [4/5], Step [700/1549], Loss: 3.216, Perplexity: 24.92
# Epoch [4/5], Step [800/1549], Loss: 3.28, Perplexity: 26.57
# Epoch [4/5], Step [900/1549], Loss: 3.011, Perplexity: 20.30
# Epoch [4/5], Step [1000/1549], Loss: 3.131, Perplexity: 22.89
# Epoch [4/5], Step [1100/1549], Loss: 3.171, Perplexity: 23.83
# Epoch [4/5], Step [1200/1549], Loss: 3.273, Perplexity: 26.39
# Epoch [4/5], Step [1300/1549], Loss: 3.004, Perplexity: 20.16
# Epoch [4/5], Step [1400/1549], Loss: 2.718, Perplexity: 15.15
# Epoch [4/5], Step [1500/1549], Loss: 3.189, Perplexity: 24.26
# Epoch [5/5], Step [0/1549], Loss: 3.078, Perplexity: 21.71
# Epoch [5/5], Step [100/1549], Loss: 2.848, Perplexity: 17.25
# Epoch [5/5], Step [200/1549], Loss: 3.133, Perplexity: 22.94
# Epoch [5/5], Step [300/1549], Loss: 3.111, Perplexity: 22.45
# Epoch [5/5], Step [400/1549], Loss: 3.035, Perplexity: 20.81
# Epoch [5/5], Step [500/1549], Loss: 2.602, Perplexity: 13.49
# Epoch [5/5], Step [600/1549], Loss: 3.064, Perplexity: 21.41
# Epoch [5/5], Step [700/1549], Loss: 2.906, Perplexity: 18.28
# Epoch [5/5], Step [800/1549], Loss: 3.054, Perplexity: 21.21
# Epoch [5/5], Step [900/1549], Loss: 2.733, Perplexity: 15.39
# Epoch [5/5], Step [1000/1549], Loss: 2.855, Perplexity: 17.38
# Epoch [5/5], Step [1100/1549], Loss: 2.86, Perplexity: 17.46
# Epoch [5/5], Step [1200/1549], Loss: 3.007, Perplexity: 20.22
# Epoch [5/5], Step [1300/1549], Loss: 2.701, Perplexity: 14.89
# Epoch [5/5], Step [1400/1549], Loss: 2.486, Perplexity: 12.02
# Epoch [5/5], Step [1500/1549], Loss: 2.9, Perplexity: 18.17

# %% [markdown]
# ## Test

# %%
sampled_text = ''

with th.no_grad():
  # Set initial hidden and cell states.
  state = (th.zeros(num_layers, 1, hidden_size).to(device),
           th.zeros(num_layers, 1, hidden_size).to(device))
  
  # Initialize by selecting one word id randomly.
  prob = th.ones(vocab_size)
  inputs = th.multinomial(prob, num_samples=1).unsqueeze(1).to(device)
  
  for i in range(num_samples):
    # Forward propagate RNN.
    output, state = model(inputs, state)
    
    # Sample a word id.
    prob = output.exp()
    word_id = th.multinomial(prob, num_samples=1).item()
    
    # Fill input with sampled word id for next time step.
    inputs.fill_(word_id)
    
    word = corpus.dictionary.idx2word[word_id]
    word = '\n' if word == '<eos>' else word + ' '
    sampled_text += word

print(sampled_text)
# Out:
# of portfolios today
# <unk> by physician <unk> a working small with new <unk> a greatest bank to head of a <unk> N portugal offset in the early years
# federal 's a <unk> $ N billion robot spacecraft fund opens plc 's equal employment since the old guard hired the <unk>
# services a woman assigned at a department of health and human services from an adequate independent agency began investigating makers <unk> in december
# the patients wo n't be solved or even talked by the <unk> sea containers
# he says a lot could act from the use
# the arab league pledged the west to american express and robert goldberg would be able to repay the company 's N guilders launch a series of communications inc. in connection with the transactions future and <unk> management co. of the current junk-bond market for sometime corp. it will become a presentation this year
# mr. stone owns never which hope that <unk> period of primary property duties to drop as stock investments in <unk> fema
# but as banks seek profits or had lower stocks in the last several months
# when a short seller of <unk> companies will have to get suggestions that much doubled from a broad u.s. and a boy the banks we recognize in programs
# <unk> can serve either way at a program that can likely the cash value of a more personal market plant
# the course of only reports followed the housing starts against those who still want to mirror the u.s. at the prestigious treasury voted
# joseph <unk> president of the british firm watson <unk> said i 'm unfortunate about it georgia-pacific promises the full plan to finance the options and to provide additional common shares
# for years the plan completed the sale of the directors is an indicated to the summer consolidation it did not want that a government could be around the $ N next year
# the government and jaguar holders remove a N N stake in newly said
# during the <unk> ford reported that tokyu occurred executives were scrambling to keep pace with a revised plan on at least part of the s&p N qintex futures markets
# the stock closed at $ N a share down $ N
# swedish auto the oil sector failed bank and <unk> also takes an estimated N million shares that account for about N N of borrowers and N <unk> used
# goodson said its growing sustained profitable office should record about $ N million for california 's existing third quarter
# but argentina economic growth is n't being influenced
# microsoft prices closed higher
# sales edged up fractionally and sears to offset a profit
# the latest drop shows as a percentage of auto manufacturing paper shares that sales totaled N million shares compared with N million francs
# but early on the dow jones offer the dow jones industrial average tumbled more accurate than previously indicated
# this week the industrial average went to these rose on 20-year concerns about the rockefeller end of this year 's budget deficit said a question was reduced last month
# for the year-earlier figure he was going to slow down the coming settlement in the 1990s
# no way even if business could fail to <unk> the coffee <unk> 's core of the game
# but two very painful led mr. <unk> arrived mr. baum 's situation questions most have been william and perfectly good
# mr. <unk> <unk> the <unk> to alleviate the missing N years ago i 'll write some identify today
# disabilities is strong and i is going to see the bloc thin mr. jones by contrast
# i feel like a character on the common fitness
# journalists say well for example
# mr. jones has invited an opening onto to the other
# he said that he has been able to face when he believes he and his wife <unk> leads the true recognition <unk> <unk> <unk> with about $ N million himself
# ad notes
# four years ago the team had intent to prove back its initial stake in the 1990s
# newspapers a lawyer for disk time on the exxon capital system ever
# we also sleep he had a $ N million after-tax baseball for an inquiry
# the carrier has raised questions about which mr. roman also recommends by a leveraged buy-out firm of apogee N and options
# for the increase in its first mainframe shares have jumped N N to a N N per-share earnings growth said
# revenue rose N N to $ N billion from $ N billion
# jeff rowe contributed N to N N monsanto lost N to N days and mrs. thatcher N N to N N
# folks which are in the best <unk> market is slowing over levels and spark profits total $ N million or about N # N
# it would be <unk> in an oct. N meeting the bankers trust whose task of default it receives the pursuit of reaching the change
# real estate developer the company uses a number of tariff patients than the u.s. and canada has a move that <unk> <unk> problems while the phillips facility could emerge in the industry 's production
# the commission suits in the u.s. and europe which surged N N in the u.s. was N N and nearly three years old
# for the nine months at&t posted earnings increases of $ N million or N cents a share compared with a loss of $ N million or N cents a share in the year-ago period
# in july unfilled profit for the latest period included $ N million from the sale of its leasing business in N
# <unk> ag added inc. said its <unk> rating and chevron also announced it to trade as it received from lending to scorpio its assets

# %% [markdown]
# ## Save model

# %%
th.save(model.state_dict(), '/tmp/rnnlm_ptb.ckpt')
