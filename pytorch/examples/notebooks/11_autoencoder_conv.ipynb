# %% [markdown]
# ## Overview

# %% [markdown]
# Autoencoder on MNIST, with analysis of embedding space.
#
# Counterpart to [11_variational_autoencoder_conv.ipynb](https://colab.research.google.com/drive/1Dp2nnlXyqOvp_PI3_pIXrzUlDOdx6ubv)
#
# ---
# **Hypothesis**
#
# Compared to VAEs, AE learns embeddings that are
# 1. not constrained to a Gaussian, offering no way to sample in z to generate images.
# 2. less semantically meaningful. Embedding arithmetic would not work as well.
#
#
#
# ---
# **Findings**
#
# 1. Evidence in favor of #1. Compare sampling from [AE](#scrollTo=57HuUU7oCe3h) vs [VAE](https://colab.research.google.com/drive/1Dp2nnlXyqOvp_PI3_pIXrzUlDOdx6ubv#scrollTo=57HuUU7oCe3h)
#
# 2. Inconclusive evidence in favor of #2.
#   > t-SNE looks similar [AE](#scrollTo=u14U-cShiTQx) vs [VAE](https://colab.research.google.com/drive/1Dp2nnlXyqOvp_PI3_pIXrzUlDOdx6ubv#scrollTo=u14U-cShiTQx)
#
#   > Embedding arithmetic works about as well, maybe slightly worse. [AE](#scrollTo=dCdYvNwF28lG) vs [VAE](https://colab.research.google.com/drive/1Dp2nnlXyqOvp_PI3_pIXrzUlDOdx6ubv#scrollTo=dCdYvNwF28lG)
#
# 3. AE has lower reconstruction error than VAE (presumably due to lack of KL term on z). [AE Training](#scrollTo=ircl6QxuOwNh)

# %% [markdown]
# ## Install

# %%
# !pip3 install torch torchvision numpy
# Out:
# Requirement already satisfied: torch in /usr/lib/python3.6/site-packages (0.4.1)
# Requirement already satisfied: torchvision in /usr/lib/python3.6/site-packages (0.2.1)
# Requirement already satisfied: numpy in /usr/lib/python3.6/site-packages (1.14.1)
# Requirement already satisfied: pillow>=4.1.1 in /usr/lib/python3.6/site-packages (from torchvision) (5.0.0)
# Requirement already satisfied: six in /usr/lib/python3.6/site-packages (from torchvision) (1.11.0)

# %% [markdown]
# ## Imports

# %%
from matplotlib import pyplot as plt
import numpy as np

import torch as th
from torch import nn
from torch.nn import functional as thf
import torchvision as tv

# %% [markdown]
# ## Config

# %%
device = th.device('cuda' if th.cuda.is_available() else 'cpu')
print(f'Using {device}')

image_shape = (1, 28, 28)
latent_size = 20
hidden_size = 400
num_epochs = 15
batch_size = 128
learning_rate = 0.001
# Out:
# Using cuda

# %% [markdown]
# ## MNIST Dataset

# %%
dataset = tv.datasets.MNIST(
    root='~/code/data/mnist/', train=True, transform=tv.transforms.ToTensor(),
    download=True)
data_loader = th.utils.data.DataLoader(
    dataset=dataset, batch_size=batch_size, shuffle=True)

test_dataset = tv.datasets.MNIST(
    root='~/code/data/mnist/', train=False, transform=tv.transforms.ToTensor(),
    download=True)
test_loader = th.utils.data.DataLoader(
    dataset=test_dataset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# ## Model

# %%
class AE(nn.Module):
  def __init__(self, h_dim, z_dim):
    super(AE, self).__init__()
    self.enc_h = nn.Sequential(
        nn.Conv2d(1, 4, 5, stride=2, padding=0),
        nn.LeakyReLU(),
        nn.Conv2d(4, 16, 5, stride=2, padding=0),
        nn.LeakyReLU(),
        #nn.Conv2d(8, 16, 5, stride=2, padding=2),
        #nn.Conv2d(16, 32, 5, stride=2, padding=2),
        
        nn.Conv2d(16, 64, 4),
        nn.LeakyReLU(),
    )
    h_dim = 64
    image_size = int(np.prod(image_shape))
    self.z = nn.Linear(h_dim, z_dim)
    self.dec_h = nn.Linear(z_dim, h_dim)
    self.dec = nn.Sequential(
        nn.ConvTranspose2d(64, 16, 4),
        nn.LeakyReLU(),
        nn.ConvTranspose2d(16, 4, 5, stride=2, output_padding=1),
        nn.LeakyReLU(),
        nn.ConvTranspose2d(4, 4, 5, stride=2, output_padding=1),
        nn.LeakyReLU(),
        nn.Conv2d(4, 1, 5, padding=2),
        nn.Sigmoid(),
    )
    
  def encode(self, x):
    h = thf.relu(self.enc_h(x))
    h = h.view(h.shape[0], -1)
    return self.z(h)
  
  def decode(self, z):
    h = self.dec_h(z)
    h = h.view(h.shape[0], -1, 1 , 1)
    x_reconst = self.dec(h)
    return x_reconst
  
  def decode_np(self, z_np):
    if z_np.ndim < 4:
      np.expand_dims(z_np, axis=0)
    z = th.from_numpy(z_np).to(device)
    return self.decode(z)
  
  def forward(self, x):
    z = self.encode(x)
    x_reconst = self.decode(z)
    return x_reconst
  
model = AE(hidden_size, latent_size).to(device)

# %% [markdown]
# ## Train

# %%
import collections
import copy

class ModelSnapshots(object):
  def __init__(self):
    self._snapshots = collections.OrderedDict()

  def snapshot(self, model, key):
    self._snapshots[key] = copy.deepcopy(model)
    
  def get(self, key):
    return self._snapshots[key]
  
model_snapshots = ModelSnapshots()

# %%
optimizer = th.optim.Adam(model.parameters(), lr=learning_rate)

num_steps = len(data_loader)
for epoch in range(num_epochs):
  for step, (x, _) in enumerate(data_loader):
    x = x.to(device)
    x_reconst = model(x)
    
    # Compute reconstruction loss.
    loss = thf.binary_cross_entropy(x_reconst, x, reduction='sum')
    
    # Backprop.
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

  print(f'Epoch [{epoch+1}/{num_epochs}], '
        f'Reconst loss: {loss.item():.4f}, ')
  model_snapshots.snapshot(model, epoch)
# Out:
# Epoch [1/15], Reconst loss: 12966.1191,
# Epoch [2/15], Reconst loss: 9854.6846,
# Epoch [3/15], Reconst loss: 8717.8447,
# Epoch [4/15], Reconst loss: 9171.6357,
# Epoch [5/15], Reconst loss: 8694.2979,
# Epoch [6/15], Reconst loss: 8169.7256,
# Epoch [7/15], Reconst loss: 8228.2236,
# Epoch [8/15], Reconst loss: 7805.2539,
# Epoch [9/15], Reconst loss: 7844.0796,
# Epoch [10/15], Reconst loss: 7205.0635,
# Epoch [11/15], Reconst loss: 7444.6167,
# Epoch [12/15], Reconst loss: 7447.2231,
# Epoch [13/15], Reconst loss: 7165.0566,
# Epoch [14/15], Reconst loss: 7075.9453,
# Epoch [15/15], Reconst loss: 7533.7930,

# %% [markdown]
# ## Test

# %%
import math
      
def sample_images(model, num_samples=1):
  with th.no_grad():
    z = th.randn(num_samples, latent_size).to(device)
    images = model.decode(z).view(-1, 1, 28, 28)
  return images.cpu().numpy()

def visualize_images(images, title=None, sub_titles=None, rows=None, cols=10):
  rows = rows or int(math.ceil(images.shape[0] / cols))
  fig, axes = plt.subplots(rows, cols, figsize=(2 * cols, 2 * rows))
  if title:
    fig.suptitle(title)
  for r in range(rows):
    for c in range(cols):
      i = r * cols + c
      image = images[i, :, :, :].squeeze()
      subplot = axes[r, c] if rows > 1 else axes[c]
      subplot.imshow(image, cmap='gray')
      subplot.axis('off')
      if sub_titles:
        subplot.title.set_text(sub_titles[i])
      
def show_image(image):
  image = image.squeeze()
  plt.imshow(image, cmap='gray')
  plt.axis('off')

# %% [markdown]
# ### Reconstructing test set

# %%
for epoch, (test_images, _) in zip(range(0, num_epochs, 2), test_loader):
  model_t = model_snapshots.get(epoch)
  test_batch = test_images.to(device)
  with th.no_grad():
    reconst_images = model_t(test_batch)
  reconst_images = reconst_images.view(-1, 1, 28, 28)
  visualize_images(test_images, title=f'Epoch {epoch+1}: original',
                   rows=1, cols=8)
  visualize_images(reconst_images, title=f'Epoch {epoch+1}: reconstructed',
                   rows=1, cols=8)

# %% [markdown]
# ### Sampling z ~ N(0, 1)

# %%
for epoch in range(0, num_epochs, 2):
  model_t = model_snapshots.get(epoch)
  images = sample_images(model_t, num_samples=batch_size)
  visualize_images(images, title=f'Epoch {epoch+1}: sampled', rows=1, cols=8)

# %% [markdown]
# ## Embedding t-SNE

# %%
def embed(model, data_loader):
  embeddings = []
  ys = []
  for x, y in data_loader:
    x = x.to(device)
    z = model.encode(x)
    embeddings.append(z.detach())
    ys.append(y.detach())
  return np.concatenate(embeddings), np.concatenate(ys)

train_embedding, train_y = embed(model, data_loader)
test_embedding, test_y = embed(model, test_loader)
print(train_embedding.shape, test_embedding.shape)
# Out:
# (60000, 20) (10000, 20)

# %%
def tsne(data, **kwargs):
  try:
    # https://github.com/DmitryUlyanov/Multicore-TSNE
    # ~50x speedup
    from MulticoreTSNE import MulticoreTSNE as TSNE
    tsne_model = TSNE(n_jobs=8, **kwargs)
  except ImportError:
    print('MulticoreTSNE not found. Falling back to sklearn.')
    from sklearn.manifold import TSNE
    kwargs['n_iter'] = kwargs.get('n_iter', 300)
    tsne_model =TSNE(**kwargs)
  return tsne_model.fit_transform(data)

def plot_tsne(data, labels):
  plt.scatter(data[:, 0], data[:, 1], c=labels,
              s=2, cmap=plt.cm.get_cmap('jet', 10))
  plt.colorbar(ticks=range(10))
  plt.clim(-0.5, 9.5)

# %% [markdown]
# ### Train (slow with n=60000)

# %%
train_tsne = tsne(train_embedding)
train_tsne.shape
# Out:
# (60000, 2)

# %%
plot_tsne(train_tsne, train_y)

# %% [markdown]
# ### Test

# %%
test_tsne = tsne(test_embedding)
test_tsne.shape
# Out:
# (10000, 2)

# %%
plot_tsne(test_tsne, test_y)

# %% [markdown]
# ## Embedding arithmetic

# %%
import functools

embedding = train_embedding
label = train_y

reduce = functools.partial(np.mean, axis=0, keepdims=True)

def em(label):
  return train_embedding[train_y == label]

def em_r(label):
  return reduce(em(label))

def lerp(z_a, z_b, ts=tuple(np.arange(-0.2, 1.2 + 1e-6, 0.2))):
  zs = np.concatenate([(1 - t) * z_a + t * z_b for t in ts])
  images = model.decode_np(zs).detach()
  visualize_images(images,
                   sub_titles=['%.2f' % t for t in ts],
                   rows=1, cols=len(ts))

def arithmetic(a, b, c, ts=(0.1, 0.2, 0.3)): 
  a_mean, b_mean, c_mean = reduce(a), reduce(b), reduce(c)
  diff = a_mean - b_mean
  
  rs = [c_mean + t * diff for t in ts]
  zs = np.concatenate([a_mean, b_mean, c_mean] + rs + [diff])
  images = model.decode_np(zs).detach()
  
  rs_titles = ['c + %.1f * (a - b)' % t for t in ts]
  visualize_images(images,
                   sub_titles=['a', 'b', 'c'] + rs_titles + ['a - b'],
                   rows=1, cols=4 + len(ts))

# %%
# Plot average of each digit
mean_digits_z = np.concatenate([reduce(em(i)) for i in range(10)])
mean_digits = model.decode_np(mean_digits_z).detach()
visualize_images(mean_digits, title='Mean digits', rows=2, cols=5)

# %% [markdown]
# ### a - b + c = ?

# %%
# 8 - 3 rounds out the left side of the digit.
arithmetic(em(8), em(3), em(5), ts=(0.3, 0.6))

# %%
# 0 - 1 makes digits fatter.
arithmetic(em(0), em(1), em(9))
arithmetic(em(0), em(1), em(3))
arithmetic(em(1), em(0), em(3))

# %%
# 0 - 1 also makes digits rounder
arithmetic(em(0), em(1), em(6))

# %% [markdown]
# ### Interpolation

# %%
lerp(em_r(0), em_r(1))

# %%
lerp(em_r(5), em_r(6))

# %%
lerp(em_r(3), em_r(8))

# %%
lerp(em_r(7), em_r(4))

# %% [markdown]
# ## Save model

# %%
th.save(model.state_dict(), '/tmp/ae.ckpt')
